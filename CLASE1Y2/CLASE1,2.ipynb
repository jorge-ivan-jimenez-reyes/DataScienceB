# %%
import os

image_path = '/Users/jorgejimenez/Documents/UP/DataScienceB/CLASE1Y2/ElectionIssuesVotersLN-superJumbo.png'

if os.path.exists(image_path):
    print("✅ La imagen existe.")
else:
    print("❌ La imagen NO existe. Revisa la ruta.")
# Out:
# ✅ La imagen existe.

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Cargar y convertir la imagen a RGB
img = Image.open(image_path).convert("RGB")

# Convertir la imagen en un array de NumPy
img_array = np.array(img)

# Mostrar la imagen
plt.imshow(img_array)
plt.axis('off')  # Ocultar ejes
plt.show()
# Out:
# <div id='3c2601d9-d766-4b2c-afd6-411d3af1067b'></div>

# %%
img = Image.open(image_path)
img.show()  # Se abrirá en el visor de imágenes predeterminado

# %%
data = [
    ['Inflation/prices', 28, 13, 35],
    ['Jobs/economy', 13, 8, 12],
    ['Immigration', 11, 2, 28],
    ['Health care', 11, 14, 2],
    ['Taxes/gov\'t spending', 6, 2, 7],
    ['Climate/environment', 5, 16, 0],
    ['Abortion', 5, 14, 3],
    ['Civil rights', 4, 11, 1],
    ['National security', 3, 3, 7],
    ['Guns', 2, 5, 2]
]

df = pd.DataFrame(data, columns=['Issue', 'Swing voters', 'Harris loyalists', 'Trump loyalists'])

# %%
titulos = ['Swing voters', 'Harris loyalists', 'Trump loyalists']
colores = ['Maroon', 'Steelblue', 'Salmon']

fig, axs = plt.subplots(1,3, figsize=(6,3),sharey=True, gridspec_kw={"wspace":0.1})
for i in range(3):
  axs[i].barh(df["Issue"], 40, color="Lightgray")
  axs[i].barh(df["Issue"], df[titulos[i]], color=colores[i])
  axs[i].set_title(titulos[i])
  if i == 0:
    axs[i].spines["left"].set_color("none")
    axs[i].spines["right"].set_color("none")
    axs[i].spines["top"].set_color("none")
    axs[i].spines["bottom"].set_color("none")
    axs[i].tick_params(axis='x', labelbottom=False, bottom=False)
  else:
    axs[i].axis("off")

for col in range (3):
  for row in range (10):
    dx=0
    c="BLack"
    weight=None
    if df.iloc[row,col+1]>15:
      dx=10
      c="White"
      weight="bold"
    axs[col].text(df.iloc[row,col+1]-dx, row, "{}%".format(df.iloc[row, col + 1]), va="center", color=c, fontweight=weight)

axs[0].invert_yaxis()
plt.suptitle("What is the most important issue to you?", size=14, x= .2,y=1.05)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     pass
#     342 else:
# --> 343     return printer(obj)
#     344 # Finally look for special method names
#     345 method = get_real_method(obj, self.print_method)
#
# File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# ...
