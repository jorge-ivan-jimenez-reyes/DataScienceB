# %%
# Importar librerías necesarias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configurar el estilo de seaborn para gráficos atractivos
sns.set(style="whitegrid", palette="muted")

# %%
# Crear un dataset simulado con las respuestas de la encuesta
data = [
    {"ID": 1, "Gender": "Male", "Age Range": "25-34", "Renewable Frequency": "Regularly",
     "Consumption Level": "High", "Efficient Use": "Daily", "Climate Concern": 5,
     "Biggest Benefit": "Lower electricity bills", "Main Concerns": "High upfront costs, ROI",
     "Investment": "$10,000 - $15,000", "Known Providers": "SunPower, Tesla Solar", "Compared Prices": "Yes"},

    {"ID": 2, "Gender": "Female", "Age Range": "35-44", "Renewable Frequency": "Occasionally",
     "Consumption Level": "Medium", "Efficient Use": "Weekly", "Climate Concern": 4,
     "Biggest Benefit": "Reducing carbon footprint", "Main Concerns": "High upfront costs, Installation complexity",
     "Investment": "$5,000 - $10,000", "Known Providers": "SolarCity", "Compared Prices": "Yes"},

    {"ID": 3, "Gender": "Non-binary", "Age Range": "18-24", "Renewable Frequency": "Rarely",
     "Consumption Level": "Low", "Efficient Use": "Occasionally", "Climate Concern": 3,
     "Biggest Benefit": "Energy independence", "Main Concerns": "None",
     "Investment": "Not sure", "Known Providers": "N/A", "Compared Prices": "No"},

    {"ID": 4, "Gender": "Prefer not to say", "Age Range": "45-54", "Renewable Frequency": "Occasionally",
     "Consumption Level": "High", "Efficient Use": "Weekly", "Climate Concern": 5,
     "Biggest Benefit": "Government incentives", "Main Concerns": "Maintenance, ROI",
     "Investment": "More than $15,000", "Known Providers": "Sunrun", "Compared Prices": "Yes"},

    {"ID": 5, "Gender": "Female", "Age Range": "55+", "Renewable Frequency": "Rarely",
     "Consumption Level": "Medium", "Efficient Use": "Rarely", "Climate Concern": 4,
     "Biggest Benefit": "Property value increase", "Main Concerns": "High upfront costs, Sunlight availability",
     "Investment": "$1,000 - $5,000", "Known Providers": "N/A", "Compared Prices": "No"},

    {"ID": 6, "Gender": "Male", "Age Range": "25-34", "Renewable Frequency": "Regularly",
     "Consumption Level": "High", "Efficient Use": "Daily", "Climate Concern": 5,
     "Biggest Benefit": "Lower electricity bills", "Main Concerns": "Installation complexity",
     "Investment": "$10,000 - $15,000", "Known Providers": "Tesla Solar", "Compared Prices": "Yes"},

    {"ID": 7, "Gender": "Female", "Age Range": "18-24", "Renewable Frequency": "Never",
     "Consumption Level": "Low", "Efficient Use": "Occasionally", "Climate Concern": 2,
     "Biggest Benefit": "Reducing carbon footprint", "Main Concerns": "High upfront costs",
     "Investment": "Not sure", "Known Providers": "N/A", "Compared Prices": "No"},

    {"ID": 8, "Gender": "Male", "Age Range": "35-44", "Renewable Frequency": "Occasionally",
     "Consumption Level": "Medium", "Efficient Use": "Weekly", "Climate Concern": 4,
     "Biggest Benefit": "Energy independence", "Main Concerns": "ROI, Installation complexity",
     "Investment": "$5,000 - $10,000", "Known Providers": "SolarCity", "Compared Prices": "Yes"},

    {"ID": 9, "Gender": "Non-binary", "Age Range": "25-34", "Renewable Frequency": "Regularly",
     "Consumption Level": "High", "Efficient Use": "Daily", "Climate Concern": 5,
     "Biggest Benefit": "Reducing carbon footprint", "Main Concerns": "High upfront costs, Maintenance",
     "Investment": "More than $15,000", "Known Providers": "SunPower", "Compared Prices": "Yes"},

    {"ID": 10, "Gender": "Female", "Age Range": "45-54", "Renewable Frequency": "Occasionally",
     "Consumption Level": "Medium", "Efficient Use": "Weekly", "Climate Concern": 3,
     "Biggest Benefit": "Other: Long-term savings", "Main Concerns": "ROI",
     "Investment": "$5,000 - $10,000", "Known Providers": "Sunrun", "Compared Prices": "No"}
]

# Convertir la lista de diccionarios a un DataFrame de pandas
df = pd.DataFrame(data)

# Mostrar el DataFrame en la consola
print("Dataset Simulado de la Encuesta:")
print(df)

# --- Visualizaciones ---

# 1. Distribución de Género
plt.figure(figsize=(8, 5))
sns.countplot(x="Gender", data=df, palette="Set2")
plt.title("Distribución de Género")
plt.xlabel("Género")
plt.ylabel("Cantidad")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 2. Distribución por Rango de Edad
plt.figure(figsize=(8, 5))
sns.countplot(x="Age Range", data=df, palette="Set3")
plt.title("Distribución por Rango de Edad")
plt.xlabel("Rango de Edad")
plt.ylabel("Cantidad")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 3. Nivel de Preocupación por el Cambio Climático (escala 1-5)
plt.figure(figsize=(8, 5))
sns.countplot(x="Climate Concern", data=df, palette="Set1")
plt.title("Nivel de Preocupación por el Cambio Climático")
plt.xlabel("Nivel (1-5)")
plt.ylabel("Cantidad")
plt.tight_layout()
plt.show()

# 4. Frecuencia de considerar energías renovables
plt.figure(figsize=(8, 5))
sns.countplot(x="Renewable Frequency", data=df, palette="coolwarm")
plt.title("Frecuencia de Considerar Energías Renovables")
plt.xlabel("Frecuencia")
plt.ylabel("Cantidad")
plt.tight_layout()
plt.show()

# 5. Resumen Estadístico Rápido
print("\nResumen del Dataset:")
print("Total de encuestados:", len(df))
print("Nivel promedio de preocupación por el cambio climático:", df["Climate Concern"].mean())
# Out:
# Dataset Simulado de la Encuesta:
#    ID             Gender Age Range Renewable Frequency Consumption Level  \
# 0   1               Male     25-34           Regularly              High
# 1   2             Female     35-44        Occasionally            Medium
# 2   3         Non-binary     18-24              Rarely               Low
# 3   4  Prefer not to say     45-54        Occasionally              High
# 4   5             Female       55+              Rarely            Medium
# 5   6               Male     25-34           Regularly              High
# 6   7             Female     18-24               Never               Low
# 7   8               Male     35-44        Occasionally            Medium
# 8   9         Non-binary     25-34           Regularly              High
# 9  10             Female     45-54        Occasionally            Medium
#
#   Efficient Use  Climate Concern            Biggest Benefit  \
# 0         Daily                5    Lower electricity bills
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración del estilo de seaborn para gráficos atractivos
sns.set(style="whitegrid", palette="muted")

# Crear dataset simulado con respuestas de la encuesta
data = [
    {"ID": 1, "Gender": "Male", "Age Range": "25-34", "Renewable Frequency": "Regularly",
     "Consumption Level": "High", "Efficient Use": "Daily", "Climate Concern": 5,
     "Biggest Benefit": "Lower electricity bills", "Main Concerns": "High upfront costs, ROI",
     "Investment": "$10,000 - $15,000", "Known Providers": "SunPower, Tesla Solar", "Compared Prices": "Yes"},

    {"ID": 2, "Gender": "Female", "Age Range": "35-44", "Renewable Frequency": "Occasionally",
     "Consumption Level": "Medium", "Efficient Use": "Weekly", "Climate Concern": 4,
     "Biggest Benefit": "Reducing carbon footprint", "Main Concerns": "High upfront costs, Installation complexity",
     "Investment": "$5,000 - $10,000", "Known Providers": "SolarCity", "Compared Prices": "Yes"},

    {"ID": 3, "Gender": "Non-binary", "Age Range": "18-24", "Renewable Frequency": "Rarely",
     "Consumption Level": "Low", "Efficient Use": "Occasionally", "Climate Concern": 3,
     "Biggest Benefit": "Energy independence", "Main Concerns": "None",
     "Investment": "Not sure", "Known Providers": "N/A", "Compared Prices": "No"},

    {"ID": 4, "Gender": "Prefer not to say", "Age Range": "45-54", "Renewable Frequency": "Occasionally",
     "Consumption Level": "High", "Efficient Use": "Weekly", "Climate Concern": 5,
     "Biggest Benefit": "Government incentives", "Main Concerns": "Maintenance, ROI",
     "Investment": "More than $15,000", "Known Providers": "Sunrun", "Compared Prices": "Yes"},

    {"ID": 5, "Gender": "Female", "Age Range": "55+", "Renewable Frequency": "Rarely",
     "Consumption Level": "Medium", "Efficient Use": "Rarely", "Climate Concern": 4,
     "Biggest Benefit": "Property value increase", "Main Concerns": "High upfront costs, Sunlight availability",
     "Investment": "$1,000 - $5,000", "Known Providers": "N/A", "Compared Prices": "No"},

    {"ID": 6, "Gender": "Male", "Age Range": "25-34", "Renewable Frequency": "Regularly",
     "Consumption Level": "High", "Efficient Use": "Daily", "Climate Concern": 5,
     "Biggest Benefit": "Lower electricity bills", "Main Concerns": "Installation complexity",
     "Investment": "$10,000 - $15,000", "Known Providers": "Tesla Solar", "Compared Prices": "Yes"},

    {"ID": 7, "Gender": "Female", "Age Range": "18-24", "Renewable Frequency": "Never",
     "Consumption Level": "Low", "Efficient Use": "Occasionally", "Climate Concern": 2,
     "Biggest Benefit": "Reducing carbon footprint", "Main Concerns": "High upfront costs",
     "Investment": "Not sure", "Known Providers": "N/A", "Compared Prices": "No"},

    {"ID": 8, "Gender": "Male", "Age Range": "35-44", "Renewable Frequency": "Occasionally",
     "Consumption Level": "Medium", "Efficient Use": "Weekly", "Climate Concern": 4,
     "Biggest Benefit": "Energy independence", "Main Concerns": "ROI, Installation complexity",
     "Investment": "$5,000 - $10,000", "Known Providers": "SolarCity", "Compared Prices": "Yes"},

    {"ID": 9, "Gender": "Non-binary", "Age Range": "25-34", "Renewable Frequency": "Regularly",
     "Consumption Level": "High", "Efficient Use": "Daily", "Climate Concern": 5,
     "Biggest Benefit": "Reducing carbon footprint", "Main Concerns": "High upfront costs, Maintenance",
     "Investment": "More than $15,000", "Known Providers": "SunPower", "Compared Prices": "Yes"},

    {"ID": 10, "Gender": "Female", "Age Range": "45-54", "Renewable Frequency": "Occasionally",
     "Consumption Level": "Medium", "Efficient Use": "Weekly", "Climate Concern": 3,
     "Biggest Benefit": "Other: Long-term savings", "Main Concerns": "ROI",
     "Investment": "$5,000 - $10,000", "Known Providers": "Sunrun", "Compared Prices": "No"}
]

# Convertir la lista de diccionarios a un DataFrame
df = pd.DataFrame(data)

# Visualización: Boxplot de la Preocupación por el Cambio Climático según la Frecuencia de considerar renovables
plt.figure(figsize=(10, 6))
sns.boxplot(x="Renewable Frequency", y="Climate Concern", data=df, palette="vlag")
plt.title("Nivel de Preocupación por el Cambio Climático según\nla Frecuencia de Considerar Energías Renovables", fontsize=14)
plt.xlabel("Frecuencia de Considerar Energías Renovables", fontsize=12)
plt.ylabel("Nivel de Preocupación (1-5)", fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/_s/hp45g33j2d710jh6kddhpsx40000gq/T/ipykernel_42849/2158645191.py:66: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Renewable Frequency", y="Climate Concern", data=df, palette="vlag")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx

# Configuración del estilo para gráficos
sns.set(style="whitegrid", palette="muted")

# Crear dataset simulado con respuestas de la encuesta
data = [
    {"ID": 1, "Gender": "Male", "Age Range": "25-34", "Renewable Frequency": "Regularly",
     "Consumption Level": "High", "Efficient Use": "Daily", "Climate Concern": 5,
     "Biggest Benefit": "Lower electricity bills", "Main Concerns": "High upfront costs, ROI",
     "Investment": "$10,000 - $15,000", "Known Providers": "SunPower, Tesla Solar", "Compared Prices": "Yes"},

    {"ID": 2, "Gender": "Female", "Age Range": "35-44", "Renewable Frequency": "Occasionally",
     "Consumption Level": "Medium", "Efficient Use": "Weekly", "Climate Concern": 4,
     "Biggest Benefit": "Reducing carbon footprint", "Main Concerns": "High upfront costs, Installation complexity",
     "Investment": "$5,000 - $10,000", "Known Providers": "SolarCity", "Compared Prices": "Yes"},

    {"ID": 3, "Gender": "Non-binary", "Age Range": "18-24", "Renewable Frequency": "Rarely",
     "Consumption Level": "Low", "Efficient Use": "Occasionally", "Climate Concern": 3,
     "Biggest Benefit": "Energy independence", "Main Concerns": "None",
     "Investment": "Not sure", "Known Providers": "N/A", "Compared Prices": "No"},

    {"ID": 4, "Gender": "Prefer not to say", "Age Range": "45-54", "Renewable Frequency": "Occasionally",
     "Consumption Level": "High", "Efficient Use": "Weekly", "Climate Concern": 5,
     "Biggest Benefit": "Government incentives", "Main Concerns": "Maintenance, ROI",
     "Investment": "More than $15,000", "Known Providers": "Sunrun", "Compared Prices": "Yes"},

    {"ID": 5, "Gender": "Female", "Age Range": "55+", "Renewable Frequency": "Rarely",
     "Consumption Level": "Medium", "Efficient Use": "Rarely", "Climate Concern": 4,
     "Biggest Benefit": "Property value increase", "Main Concerns": "High upfront costs, Sunlight availability",
     "Investment": "$1,000 - $5,000", "Known Providers": "N/A", "Compared Prices": "No"},

    {"ID": 6, "Gender": "Male", "Age Range": "25-34", "Renewable Frequency": "Regularly",
     "Consumption Level": "High", "Efficient Use": "Daily", "Climate Concern": 5,
     "Biggest Benefit": "Lower electricity bills", "Main Concerns": "Installation complexity",
     "Investment": "$10,000 - $15,000", "Known Providers": "Tesla Solar", "Compared Prices": "Yes"},

    {"ID": 7, "Gender": "Female", "Age Range": "18-24", "Renewable Frequency": "Never",
     "Consumption Level": "Low", "Efficient Use": "Occasionally", "Climate Concern": 2,
     "Biggest Benefit": "Reducing carbon footprint", "Main Concerns": "High upfront costs",
     "Investment": "Not sure", "Known Providers": "N/A", "Compared Prices": "No"},

    {"ID": 8, "Gender": "Male", "Age Range": "35-44", "Renewable Frequency": "Occasionally",
     "Consumption Level": "Medium", "Efficient Use": "Weekly", "Climate Concern": 4,
     "Biggest Benefit": "Energy independence", "Main Concerns": "ROI, Installation complexity",
     "Investment": "$5,000 - $10,000", "Known Providers": "SolarCity", "Compared Prices": "Yes"},

    {"ID": 9, "Gender": "Non-binary", "Age Range": "25-34", "Renewable Frequency": "Regularly",
     "Consumption Level": "High", "Efficient Use": "Daily", "Climate Concern": 5,
     "Biggest Benefit": "Reducing carbon footprint", "Main Concerns": "High upfront costs, Maintenance",
     "Investment": "More than $15,000", "Known Providers": "SunPower", "Compared Prices": "Yes"},

    {"ID": 10, "Gender": "Female", "Age Range": "45-54", "Renewable Frequency": "Occasionally",
     "Consumption Level": "Medium", "Efficient Use": "Weekly", "Climate Concern": 3,
     "Biggest Benefit": "Other: Long-term savings", "Main Concerns": "ROI",
     "Investment": "$5,000 - $10,000", "Known Providers": "Sunrun", "Compared Prices": "No"}
]

# Convertir la lista de diccionarios a un DataFrame de pandas
df = pd.DataFrame(data)

# Visualización 1: Boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x="Renewable Frequency", y="Climate Concern", data=df, palette="vlag")
plt.title("Preocupación Ambiental vs. Frecuencia de Considerar Renovables", fontsize=14)
plt.xlabel("Frecuencia de Considerar Energías Renovables", fontsize=12)
plt.ylabel("Nivel de Preocupación (1-5)", fontsize=12)
plt.tight_layout()
plt.show()

# Resumen rápido de insights
print("Total de encuestados:", len(df))
print("Promedio de preocupación por el cambio climático:", df["Climate Concern"].mean())
print("Distribución de inversión:")
print(df["Investment"].value_counts())

# Basándonos en estos insights:
# - Un alto porcentaje de encuestados muestra interés en las energías renovables.
# - Los niveles de preocupación ambiental son elevados.
# - La mayoría está dispuesta a invertir montos significativos.
#
# Esto sugiere que, con la estrategia adecuada, vender paneles solares es rentable.

# --------------------------------------------------------------
# Creación del diagrama que relaciona las preguntas y la decisión de negocio

# Crear un gráfico dirigido
G = nx.DiGraph()

# Agregar nodos (cada uno representa un bloque de preguntas)
G.add_node("Survey")
G.add_node("Demographics\n(Gender, Age Range)")
G.add_node("Energy Behavior\n(Renewable Frequency,\nConsumption, Efficiency)")
G.add_node("Environmental Attitude\n(Climate Concern)")
G.add_node("Investment\n(Willingness to Invest)")
G.add_node("Business Decision\n(Sell Solar Panels?)")

# Agregar aristas para conectar los nodos
edges = [
    ("Survey", "Demographics\n(Gender, Age Range)"),
    ("Survey", "Energy Behavior\n(Renewable Frequency,\nConsumption, Efficiency)"),
    ("Survey", "Environmental Attitude\n(Climate Concern)"),
    ("Survey", "Investment\n(Willingness to Invest)"),
    ("Demographics\n(Gender, Age Range)", "Business Decision\n(Sell Solar Panels?)"),
    ("Energy Behavior\n(Renewable Frequency,\nConsumption, Efficiency)", "Business Decision\n(Sell Solar Panels?)"),
    ("Environmental Attitude\n(Climate Concern)", "Business Decision\n(Sell Solar Panels?)"),
    ("Investment\n(Willingness to Invest)", "Business Decision\n(Sell Solar Panels?)"),
]
G.add_edges_from(edges)

# Dibujar el grafo
plt.figure(figsize=(10, 7))
pos = nx.spring_layout(G, seed=42)
nx.draw_networkx(G, pos, with_labels=True, node_color="skyblue", node_size=3000, font_size=10, font_weight="bold", arrows=True)
plt.title("Diagrama de las Preguntas y Datos del Survey\npara la Decisión de Vender Paneles Solares", fontsize=14)
plt.axis("off")
plt.show()
# Out:
# /var/folders/_s/hp45g33j2d710jh6kddhpsx40000gq/T/ipykernel_42849/4200700100.py:67: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Renewable Frequency", y="Climate Concern", data=df, palette="vlag")
# Total de encuestados: 10
# Promedio de preocupación por el cambio climático: 4.0
# Distribución de inversión:
# Investment
# $5,000 - $10,000     3
# $10,000 - $15,000    2
# Not sure             2
# More than $15,000    2
# $1,000 - $5,000      1
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx

# Configuración del estilo para gráficos
sns.set(style="whitegrid", palette="muted")

# Crear dataset simulado con respuestas de la encuesta
data = [
    {"ID": 1, "Gender": "Male", "Age Range": "25-34", "Renewable Frequency": "Regularly",
     "Consumption Level": "High", "Efficient Use": "Daily", "Climate Concern": 5,
     "Biggest Benefit": "Lower electricity bills", "Main Concerns": "High upfront costs, ROI",
     "Investment": "$10,000 - $15,000", "Known Providers": "SunPower, Tesla Solar", "Compared Prices": "Yes"},

    {"ID": 2, "Gender": "Female", "Age Range": "35-44", "Renewable Frequency": "Occasionally",
     "Consumption Level": "Medium", "Efficient Use": "Weekly", "Climate Concern": 4,
     "Biggest Benefit": "Reducing carbon footprint", "Main Concerns": "High upfront costs, Installation complexity",
     "Investment": "$5,000 - $10,000", "Known Providers": "SolarCity", "Compared Prices": "Yes"},

    {"ID": 3, "Gender": "Non-binary", "Age Range": "18-24", "Renewable Frequency": "Rarely",
     "Consumption Level": "Low", "Efficient Use": "Occasionally", "Climate Concern": 3,
     "Biggest Benefit": "Energy independence", "Main Concerns": "None",
     "Investment": "Not sure", "Known Providers": "N/A", "Compared Prices": "No"},

    {"ID": 4, "Gender": "Prefer not to say", "Age Range": "45-54", "Renewable Frequency": "Occasionally",
     "Consumption Level": "High", "Efficient Use": "Weekly", "Climate Concern": 5,
     "Biggest Benefit": "Government incentives", "Main Concerns": "Maintenance, ROI",
     "Investment": "More than $15,000", "Known Providers": "Sunrun", "Compared Prices": "Yes"},

    {"ID": 5, "Gender": "Female", "Age Range": "55+", "Renewable Frequency": "Rarely",
     "Consumption Level": "Medium", "Efficient Use": "Rarely", "Climate Concern": 4,
     "Biggest Benefit": "Property value increase", "Main Concerns": "High upfront costs, Sunlight availability",
     "Investment": "$1,000 - $5,000", "Known Providers": "N/A", "Compared Prices": "No"},

    {"ID": 6, "Gender": "Male", "Age Range": "25-34", "Renewable Frequency": "Regularly",
     "Consumption Level": "High", "Efficient Use": "Daily", "Climate Concern": 5,
     "Biggest Benefit": "Lower electricity bills", "Main Concerns": "Installation complexity",
     "Investment": "$10,000 - $15,000", "Known Providers": "Tesla Solar", "Compared Prices": "Yes"},

    {"ID": 7, "Gender": "Female", "Age Range": "18-24", "Renewable Frequency": "Never",
     "Consumption Level": "Low", "Efficient Use": "Occasionally", "Climate Concern": 2,
     "Biggest Benefit": "Reducing carbon footprint", "Main Concerns": "High upfront costs",
     "Investment": "Not sure", "Known Providers": "N/A", "Compared Prices": "No"},

    {"ID": 8, "Gender": "Male", "Age Range": "35-44", "Renewable Frequency": "Occasionally",
     "Consumption Level": "Medium", "Efficient Use": "Weekly", "Climate Concern": 4,
     "Biggest Benefit": "Energy independence", "Main Concerns": "ROI, Installation complexity",
     "Investment": "$5,000 - $10,000", "Known Providers": "SolarCity", "Compared Prices": "Yes"},

    {"ID": 9, "Gender": "Non-binary", "Age Range": "25-34", "Renewable Frequency": "Regularly",
     "Consumption Level": "High", "Efficient Use": "Daily", "Climate Concern": 5,
     "Biggest Benefit": "Reducing carbon footprint", "Main Concerns": "High upfront costs, Maintenance",
     "Investment": "More than $15,000", "Known Providers": "SunPower", "Compared Prices": "Yes"},

    {"ID": 10, "Gender": "Female", "Age Range": "45-54", "Renewable Frequency": "Occasionally",
     "Consumption Level": "Medium", "Efficient Use": "Weekly", "Climate Concern": 3,
     "Biggest Benefit": "Other: Long-term savings", "Main Concerns": "ROI",
     "Investment": "$5,000 - $10,000", "Known Providers": "Sunrun", "Compared Prices": "No"}
]

# Convertir la lista de diccionarios a un DataFrame de pandas
df = pd.DataFrame(data)

# Crear una columna numérica para la inversión aproximada
investment_map = {
    "$1,000 - $5,000": 3000,
    "$5,000 - $10,000": 7500,
    "$10,000 - $15,000": 12500,
    "More than $15,000": 17500,
    "Not sure": None
}
df["Investment Numeric"] = df["Investment"].map(investment_map)

# Gráfica 2: Scatter plot que relaciona la preocupación ambiental con la inversión estimada
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="Climate Concern", y="Investment Numeric", hue="Renewable Frequency", s=100, palette="deep")
plt.title("Relación entre Preocupación Ambiental y Estimación de Inversión", fontsize=14)
plt.xlabel("Nivel de Preocupación Ambiental (1-5)", fontsize=12)
plt.ylabel("Inversión Estimada (USD)", fontsize=12)
plt.tight_layout()
plt.show()

# Interpretación rápida:
# - Si observamos que aquellos con alta preocupación ambiental (niveles 4-5) tienden a tener una mayor inversión estimada,
#   podemos inferir que existe un segmento de clientes dispuestos a invertir en paneles solares.
# - Esto es un indicador clave que sugiere la rentabilidad de vender paneles solares,
#   siempre que se complementen con estrategias de marketing y financiamiento adecuadas.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import collections

# Configuración del estilo para gráficos
sns.set(style="whitegrid", palette="pastel")

# Crear dataset simulado con respuestas de la encuesta
data = [
    {"ID": 1, "Gender": "Male", "Age Range": "25-34", "Renewable Frequency": "Regularly",
     "Consumption Level": "High", "Efficient Use": "Daily", "Climate Concern": 5,
     "Biggest Benefit": "Lower electricity bills", "Main Concerns": "High upfront costs, ROI",
     "Investment": "$10,000 - $15,000", "Known Providers": "SunPower, Tesla Solar", "Compared Prices": "Yes"},

    {"ID": 2, "Gender": "Female", "Age Range": "35-44", "Renewable Frequency": "Occasionally",
     "Consumption Level": "Medium", "Efficient Use": "Weekly", "Climate Concern": 4,
     "Biggest Benefit": "Reducing carbon footprint", "Main Concerns": "High upfront costs, Installation complexity",
     "Investment": "$5,000 - $10,000", "Known Providers": "SolarCity", "Compared Prices": "Yes"},

    {"ID": 3, "Gender": "Non-binary", "Age Range": "18-24", "Renewable Frequency": "Rarely",
     "Consumption Level": "Low", "Efficient Use": "Occasionally", "Climate Concern": 3,
     "Biggest Benefit": "Energy independence", "Main Concerns": "None",
     "Investment": "Not sure", "Known Providers": "N/A", "Compared Prices": "No"},

    {"ID": 4, "Gender": "Prefer not to say", "Age Range": "45-54", "Renewable Frequency": "Occasionally",
     "Consumption Level": "High", "Efficient Use": "Weekly", "Climate Concern": 5,
     "Biggest Benefit": "Government incentives", "Main Concerns": "Maintenance, ROI",
     "Investment": "More than $15,000", "Known Providers": "Sunrun", "Compared Prices": "Yes"},

    {"ID": 5, "Gender": "Female", "Age Range": "55+", "Renewable Frequency": "Rarely",
     "Consumption Level": "Medium", "Efficient Use": "Rarely", "Climate Concern": 4,
     "Biggest Benefit": "Property value increase", "Main Concerns": "High upfront costs, Sunlight availability",
     "Investment": "$1,000 - $5,000", "Known Providers": "N/A", "Compared Prices": "No"},

    {"ID": 6, "Gender": "Male", "Age Range": "25-34", "Renewable Frequency": "Regularly",
     "Consumption Level": "High", "Efficient Use": "Daily", "Climate Concern": 5,
     "Biggest Benefit": "Lower electricity bills", "Main Concerns": "Installation complexity",
     "Investment": "$10,000 - $15,000", "Known Providers": "Tesla Solar", "Compared Prices": "Yes"},

    {"ID": 7, "Gender": "Female", "Age Range": "18-24", "Renewable Frequency": "Never",
     "Consumption Level": "Low", "Efficient Use": "Occasionally", "Climate Concern": 2,
     "Biggest Benefit": "Reducing carbon footprint", "Main Concerns": "High upfront costs",
     "Investment": "Not sure", "Known Providers": "N/A", "Compared Prices": "No"},

    {"ID": 8, "Gender": "Male", "Age Range": "35-44", "Renewable Frequency": "Occasionally",
     "Consumption Level": "Medium", "Efficient Use": "Weekly", "Climate Concern": 4,
     "Biggest Benefit": "Energy independence", "Main Concerns": "ROI, Installation complexity",
     "Investment": "$5,000 - $10,000", "Known Providers": "SolarCity", "Compared Prices": "Yes"},

    {"ID": 9, "Gender": "Non-binary", "Age Range": "25-34", "Renewable Frequency": "Regularly",
     "Consumption Level": "High", "Efficient Use": "Daily", "Climate Concern": 5,
     "Biggest Benefit": "Reducing carbon footprint", "Main Concerns": "High upfront costs, Maintenance",
     "Investment": "More than $15,000", "Known Providers": "SunPower", "Compared Prices": "Yes"},

    {"ID": 10, "Gender": "Female", "Age Range": "45-54", "Renewable Frequency": "Occasionally",
     "Consumption Level": "Medium", "Efficient Use": "Weekly", "Climate Concern": 3,
     "Biggest Benefit": "Other: Long-term savings", "Main Concerns": "ROI",
     "Investment": "$5,000 - $10,000", "Known Providers": "Sunrun", "Compared Prices": "No"}
]

# Convertir la lista de diccionarios a un DataFrame
df = pd.DataFrame(data)

# Crear una figura con subplots para cada pregunta
fig, axes = plt.subplots(3, 3, figsize=(20, 18))
axes = axes.flatten()

# 1. Distribución de Género
sns.countplot(x="Gender", data=df, ax=axes[0])
axes[0].set_title('Gender Distribution')
axes[0].tick_params(axis='x', rotation=45)

# 2. Distribución por Rango de Edad
sns.countplot(x="Age Range", data=df, ax=axes[1])
axes[1].set_title('Age Range Distribution')
axes[1].tick_params(axis='x', rotation=45)

# 3. Frecuencia de Considerar Energías Renovables
sns.countplot(x="Renewable Frequency", data=df, ax=axes[2])
axes[2].set_title('Renewable Frequency')
axes[2].tick_params(axis='x', rotation=45)

# 4. Nivel de Consumo Eléctrico
sns.countplot(x="Consumption Level", data=df, ax=axes[3])
axes[3].set_title('Electricity Consumption Level')
axes[3].tick_params(axis='x', rotation=45)

# 5. Uso de Productos Eficientes
sns.countplot(x="Efficient Use", data=df, ax=axes[4])
axes[4].set_title('Use of Energy-efficient Products')
axes[4].tick_params(axis='x', rotation=45)

# 6. Preocupación por el Cambio Climático
sns.countplot(x="Climate Concern", data=df, ax=axes[5])
axes[5].set_title('Climate Concern (1-5)')

# 7. Mayor Beneficio de la Energía Solar
sns.countplot(x="Biggest Benefit", data=df, ax=axes[6])
axes[6].set_title('Biggest Benefit of Switching to Solar')
axes[6].tick_params(axis='x', rotation=45)

# 8. Principales Preocupaciones
# Separar las respuestas múltiples y contarlas
all_concerns = []
for item in df["Main Concerns"]:
    if pd.isnull(item):
        continue
    for concern in item.split(','):
        all_concerns.append(concern.strip())
concerns_count = collections.Counter(all_concerns)
axes[7].bar(concerns_count.keys(), concerns_count.values(), color='skyblue')
axes[7].set_title('Main Concerns about Switching')
axes[7].tick_params(axis='x', rotation=45)

# 9. Distribución de la Inversión
sns.countplot(x="Investment", data=df, ax=axes[8])
axes[8].set_title('Investment Distribution')
axes[8].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# Gráfica adicional: Comparación de Precios (Yes/No)
plt.figure(figsize=(6, 4))
sns.countplot(x="Compared Prices", data=df, palette="pastel")
plt.title('Have you ever compared prices?')
plt.xlabel('Compared Prices')
plt.ylabel('Count')
plt.show()
# Out:
# /var/folders/_s/hp45g33j2d710jh6kddhpsx40000gq/T/ipykernel_42849/2113839566.py:126: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Compared Prices", data=df, palette="pastel")
